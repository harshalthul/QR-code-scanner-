# %% [markdown]
# # Build QR Scanner APK using Buildozer
#
# Use this notebook to compile your Kivy application into an Android APK.
#
# **Steps:**
# 1. Upload your `main.py` and `buildozer.spec` files to the Colab runtime (drag and drop them into the Files pane on the left).
# 2. Run the cells below in order.

# %%
# !pip install buildozer
# !sudo apt-get install -y git zip unzip openjdk-17-jdk python3-pip autoconf libtool pkg-config zlib1g-dev libncurses5-dev libncursesw5-dev libtinfo5 cmake libffi-dev libssl-dev automake libtool-bin gettext
# !pip install --upgrade Cython==0.29.33

# %%
# Clean up any previous builds if needed
# !buildozer android clean

# %%
# Build the APK
# The first run takes a long time (downloads NDK/SDK/recipes)
# !buildozer android debug

# %% [markdown]
# ## Download APK
# Once the build finishes (it says "Application pushed" or just ends successfully), check the `bin/` folder in the Files pane to find your `.apk` file. Download it and install it on your phone.
